# %% [markdown]
# # PCA Analysis for S&P 500 ticker data.
# Cannot find reliable futures data.

# %%
import numpy as np
import pandas as pd
import yfinance as yf


# FIX TICKERS

# Retrieve current constituents list from Wikipedia
constituents = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# Handle Failed Downloads and remove corresponding tickers
tickers = list(constituents["Symbol"])
tickers.remove('BRK.B')
tickers.remove('BF.B')


#-------------------------------------------------------------------------------------------------#

# Download the data with yfinance
price_data = yf.download(
    tickers=tickers,
    period="5y",
    interval="1mo",
    group_by='column',
    auto_adjust=False,
    prepost=False,
    threads=True,
    proxy=None
)

# Drop full-NaN observations
price_data = price_data["Adj Close"].dropna(thresh=1)

# Omit last price observation and calculate returns
price_data = price_data.iloc[:-1].pct_change().iloc[1:]

# Outlier processing
price_data[price_data > 0.5] = np.nan
price_data[price_data < -0.5] = np.nan

# Forward-fill NaN values for a more robust approach
return_data = price_data.fillna(method='ffill')
# Out:
# [*********************100%%**********************]  501 of 501 completed

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer

# Assuming return_data is your dataset

# Replace NaN values with mean using SimpleImputer
imputer = SimpleImputer(strategy='mean')
imputed_data = imputer.fit_transform(return_data)

# Apply PCA
pca = PCA(n_components=5)
fitted = pca.fit(imputed_data)

# Plot the first two eigenvectors
fig, ax = plt.subplots(figsize=[15,10])
ax.plot(pca.components_[0], label='First Eigenvector')
ax.plot(pca.components_[1]+0.2, label='Second Eigenvector')
plt.xlabel('Feature Index')
plt.ylabel('Eigenvector Value')
plt.title('First Two Eigenvectors')
plt.legend()
plt.show()

# %%
# Plot explained variance ratio
plt.figure(figsize=[10, 6])
plt.plot(np.arange(1, len(pca.explained_variance_ratio_) + 1), 
         pca.explained_variance_ratio_, 
         marker='o')
plt.xlabel('Principal Component', fontsize=14)
plt.ylabel('Explained Variance Ratio', fontsize=14)
plt.title('Explained Variance Ratio for Each Principal Component', fontsize=16)
plt.grid(True)
plt.show()
